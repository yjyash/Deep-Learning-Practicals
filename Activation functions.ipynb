# %%
e = 2.718

# %%
#implementation of tanh

# %%
x=-19

# %%
y = ((e**x)-(e**-x))/((e**x)+(e**-x))

# %%
y
# Out:
# -1.0

# %%
#Report shows that x=0 then y=0
#if x = 19 then y=1
#if x = -19 then y=-1

# %%
#implementation of relu

# %%
x=-1

# %%
y = max(0,x)

# %%
y
# Out:
# 0

# %%
#Report shows that x =0  then y=0
#if x > 0 then y > 0
#if x < 0 then y=0

# %%
#implementation of sigmoid

# %%
x = 100

# %%
y = 1/(1+e**-x)

# %%
y
# Out:
# 1.0

# %%
#Report shows that x=0 then y = 0.5
#if x > 0 then y > 0.5
#if x < 0 then y < 0.

# %%
#implementation of softmax

# %%
x=[11,22,33]

# %%
y = e**x/(sum(e**x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-5da819d62ba2> in <cell line: 1>()
# ----> 1 y = e**x/(sum(e**x))
#
# TypeError: unsupported operand type(s) for ** or pow(): 'float' and 'list'

# %%
y
