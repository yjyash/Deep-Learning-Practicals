# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('/content/Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
x = df.drop(['price'],axis=1)
y = df['price']

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories
# 0    7420         4          2        3
# 1    8960         4          4        4
# 2    9960         3          2        2
# 3    7500         4          2        2
# 4    7420         4          1        2
# ..    ...       ...        ...      ...
# 540  3000         2          1        1
# 541  2400         3          1        1
# 542  3620         2          1        1
# 543  2910         3          1        1
# 544  3850         3          1        2
#
# [545 rows x 4 columns]

# %%
x = x.iloc[:,0:4]

# %%
mm  =MinMaxScaler()
y=mm.fit_transform(y.values.reshape(-1,1))

# %%
y
# Out:
# array([[1.        ],
#        [0.90909091],
#        [0.90909091],
#        [0.90606061],
#        [0.83636364],
#        [0.78787879],
#        [0.72727273],
#        [0.72727273],
#        [0.7030303 ],
#        [0.6969697 ],
#        [0.6969697 ],
#        [0.68666667],
#        [0.65454545],
#        [0.64848485],
#        [0.64848485],
#        [0.63636364],
#        [0.63636364],
#        [0.62424242],
#        [0.61818182],
#        [0.61515152],
#        [0.60606061],
#        [0.6       ],
#        [0.5969697 ],
#        [0.5969697 ],
#        [0.59090909],
#        [0.58787879],
#        [0.58121212],
#        [0.57575758],
#        [0.57575758],
#        [0.57575758],
#        [0.57575758],
#        [0.57575758],
#        [0.56666667],
#        [0.55757576],
#        [0.55151515],
#        [0.54813333],
#        [0.54484848],
#        [0.53939394],
#        [0.53787879],
#        [0.53333333],
#        [0.53030303],
#        [0.52727273],
#        [0.51515152],
# ...

# %%
model = Sequential()
model.add(Dense(782,activation='relu'))
model.add(Dense(782,activation='relu'))
model.add(Dense(782,activation='relu'))
model.add(Dense(828,activation='relu'))
model.add(Dense(182,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.compile(optimizer='adam',loss='mean_absolute_error',metrics=['mean_absolute_error'])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 8.9985 - mean_absolute_error: 8.9985
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.8993 - mean_absolute_error: 1.8993
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.0466 - mean_absolute_error: 1.0466
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.8213 - mean_absolute_error: 0.8213
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3415 - mean_absolute_error: 0.3415
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.1681 - mean_absolute_error: 0.1681
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.2026 - mean_absolute_error: 0.2026
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.2266 - mean_absolute_error: 0.2266
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.1318 - mean_absolute_error: 0.1318
# Epoch 10/50
# ...

# %%
pred=model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-7d330dfea6bd> in <cell line: 1>()
# ----> 1 pred=model.predict(x_test)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     106       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107   ctx.ensure_initialized()
# --> 108   return ops.EagerTensor(value, ctx.device_name, dtype)
#     109
#     110
#
# ...

# %%
for i  in range(len(pred)):
  print(pred[i],y_test[i],sep="----------")
# Out:
# [4281604.]----------[7.37715845e+20]
# [4281604.]----------[4.6690877e+20]
# [4281604.]----------[4.57570595e+20]
# [4281604.]----------[6.35929738e+20]
# [4281604.]----------[1.02719927e+21]
# [4281604.]----------[3.3617432e+20]
# [4281604.]----------[7.4705402e+20]
# [4281604.]----------[9.05802995e+20]
# [4281604.]----------[9.80508395e+20]
# [4281604.]----------[5.2293782e+20]
# [4281604.]----------[4.57570595e+20]
# [4281604.]----------[4.94923295e+20]
# [4281604.]----------[9.19810258e+20]
# [4281604.]----------[5.69628695e+20]
# [4281604.]----------[5.34610539e+20]
# [4281604.]----------[4.06210633e+20]
# [4281604.]----------[1.62951156e+21]
# [4281604.]----------[7.6573037e+20]
# [4281604.]----------[8.26428508e+20]
# [4281604.]----------[7.18105678e+20]
# [4281604.]----------[6.63010445e+20]
# [4281604.]----------[4.52901508e+20]
# [4281604.]----------[6.7234862e+20]
# [4281604.]----------[8.68450295e+20]
# [4281604.]----------[4.8558512e+20]
# ...

# %%
for i  in range(len(pred)):
  print(pred[i]-y_test[i])
# Out:
# [-1856544.25]
# [119791.75]
# [-824957.5]
# [-1823761.75]
# [-3911134.5]
# [360247.25]
# [-721577.]
# [-1477042.]
# [-3700050.]
# [-403343.5]
# [-366640.]
# [-53500.25]
# [-2784206.75]
# [-515196.5]
# [-1048432.75]
# [6245.75]
# [-8156603.5]
# [-2255572.25]
# [-2685542.25]
# [-1613900.25]
# [-858181.75]
# [-72205.25]
# [-100462.]
# [-2241210.]
# [-755923.75]
# [1141224.75]
# [-2019993.5]
# [125261.]
# [-655273.5]
# [-217440.25]
# [-1708428.5]
# [-1511220.75]
# [-2492882.]
# [-9259604.25]
# [-828789.]
# [-213954.5]
# [316420.75]
# [-974321.]
# [-1043299.]
# [-3963150.]
# [-4952706.25]
# [571770.25]
# [889363.5]
# [-2475183.5]
# [-2350938.25]
# [-1549479.]
# [-2196456.25]
# [-617565.5]
# [-1980400.]
# [-1663420.75]
# [455198.]
# [-2020176.75]
# [-3477191.]
# [-4253860.]
# [-1557123.25]
# [-5793606.]
# [-721884.5]
# [-3208966.5]
# [-2335814.25]
# [278243.25]
# [-4555853.]
# [-1064945.25]
# [-240190.]
# [-980619.25]
# [-1310552.]
# [-173868.25]
# [-109533.]
# [-352310.75]
# ...

# %%
pred = mm.inverse_transform(pred)

# %%
y_test = mm.inverse_transform(y_test)
